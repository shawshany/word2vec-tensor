# %%
"""Basic word2vec example."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)
#由于网速问题，我自己用迅雷下载后再复制到tmp目录下了

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  322.959960938
# Nearest to be: neurotic, settling, reflects, faithfulness, naive, acapulco, maradns, athenian,
# Nearest to one: reconfigurable, tfl, progressively, rebuke, espresso, delhi, mogul, rejection,
# Nearest to its: directx, kazakhs, totalled, pwn, candler, damaging, croft, limited,
# Nearest to other: ebooks, another, asymptotically, mitre, exponent, mangaverse, unlikely, tunisian,
# Nearest to often: neodymium, ram, droughts, deadlines, vries, oblivious, prefrontal, fireman,
# Nearest to their: disuse, ching, aileen, aspect, crass, kilobyte, david, woolwich,
# Nearest to an: melodic, demo, tamed, surrounds, affairs, folks, traveled, airflow,
# Nearest to will: safl, sizeable, transoxiana, grapheme, aquariums, gec, franks, dresses,
# Nearest to and: developing, truthful, staffing, falco, priorities, vilas, york, fugal,
# Nearest to also: troughs, crassus, fanatical, renovated, protests, kumasi, cyaxares, eradicated,
# Nearest to can: macy, ons, majorca, facilities, ensured, vall, basenjis, grantham,
# Nearest to such: kluwer, adonai, angelo, scholar, amazed, crisis, floods, seventeen,
# Nearest to first: pounder, southerners, flavor, lifted, gx, expansionist, palaestina, gunpoint,
# Nearest to on: adair, residuals, saxophonist, alfalfa, ferry, pitchfork, tychonoff, shen,
# Nearest to many: despotism, os, moria, vitrification, polisario, seif, discrimination, steamships,
# Nearest to see: seclusion, surveyed, decks, cpu, reinstating, legal, diverted, axelrod,
# Average loss at step  2000 :  113.216556106
# Average loss at step  4000 :  52.6789351492
# Average loss at step  6000 :  33.5848629351
# Average loss at step  8000 :  23.3123515862
# Average loss at step  10000 :  17.7391539434
# Nearest to be: have, according, naive, reflects, is, burgess, players, devices,
# Nearest to one: archie, two, zero, nine, UNK, altenberg, phi, sheet,
# Nearest to its: their, logic, noble, abandonment, limited, archie, the, hart,
# Nearest to other: archie, another, martin, yum, sheen, ataxia, deity, ngc,
# Nearest to often: ram, droughts, expressions, bonding, involving, founded, martial, mogadishu,
# Nearest to their: archie, its, theologians, a, conceal, disuse, behavioral, aspect,
# Nearest to an: european, traveled, kubitzki, leipzig, himself, panel, sergei, survey,
# Nearest to will: grapheme, she, promoted, archie, that, studios, molinari, airline,
# Nearest to and: in, of, archie, UNK, or, phi, the, s,
# Nearest to also: protests, lady, channel, papyrus, murray, constantly, troughs, biodiesel,
# Nearest to can: aberdeenshire, molinari, facilities, sigma, unit, dylan, v, ensured,
# Nearest to such: moses, song, scholar, crisis, floods, ending, far, asking,
# Nearest to first: archie, phi, var, sagan, save, lifted, extracted, wide,
# Nearest to on: in, one, and, poirot, pseudocode, for, voyage, trench,
# Nearest to many: the, os, omega, require, archie, addition, giant, hep,
# Nearest to see: cpu, victory, surveyed, legal, is, modifications, constitutional, mathbf,
# Average loss at step  12000 :  14.3910683398
# Average loss at step  14000 :  11.8988511987
# Average loss at step  16000 :  9.99308452916
# Average loss at step  18000 :  8.60683647645
# Average loss at step  20000 :  7.91120301044
# Nearest to be: have, according, is, by, was, acapulco, settling, circ,
# Nearest to one: two, operatorname, eight, nine, three, four, archie, seven,
# Nearest to its: the, their, his, this, logic, noble, reacting, hart,
# Nearest to other: archie, another, UNK, asymptotically, print, yum, opus, quell,
# Nearest to often: droughts, expressions, elizabeth, it, ram, involving, mogadishu, martial,
# Nearest to their: its, the, his, archie, aquila, operatorname, fisherman, disuse,
# Nearest to an: the, traveled, acacia, himself, aoc, trivia, sergei, european,
# Nearest to will: would, can, she, franks, grapheme, that, blockage, promoted,
# Nearest to and: or, in, archie, of, for, circ, dasyprocta, gb,
# Nearest to also: lady, protests, dasyprocta, papyrus, which, channel, not, articulated,
# Nearest to can: will, would, if, facilities, to, aberdeenshire, molinari, smooth,
# Nearest to such: moses, ishmael, far, floods, crisis, acknowledge, scholar, angelo,
# Nearest to first: antoninus, archie, and, spy, phi, antihydrogen, at, leagues,
# Nearest to on: in, for, agouti, and, poirot, dasyprocta, by, of,
# Nearest to many: the, acacia, omega, archie, dasyprocta, most, require, polisario,
# Nearest to see: cpu, is, victory, xbox, legal, surveyed, constitutional, blank,
# Average loss at step  22000 :  6.91951406121
# Average loss at step  24000 :  6.95719094825
# Average loss at step  26000 :  6.71420395112
# Average loss at step  28000 :  6.31610735929
# Average loss at step  30000 :  5.94892657411
# Nearest to be: have, according, by, is, was, been, were, are,
# Nearest to one: two, eight, four, operatorname, seven, agouti, three, archie,
# Nearest to its: their, the, his, this, reacting, noble, operatorname, damaging,
# Nearest to other: another, archie, print, otimes, civilizations, martin, asymptotically, quell,
# Nearest to often: it, expressions, droughts, elizabeth, amphibious, there, mogadishu, ram,
# Nearest to their: its, his, the, archie, operatorname, aquila, woolwich, disuse,
# Nearest to an: the, traveled, himself, almighty, melodic, acacia, aoc, tajikistan,
# Nearest to will: would, can, she, puns, franks, blockage, could, but,
# Nearest to and: or, archie, abet, dasyprocta, but, circ, one, of,
# Nearest to also: which, lady, protests, not, dasyprocta, that, papyrus, it,
# Nearest to can: would, will, could, to, if, amalthea, aberdeenshire, facilities,
# Nearest to such: far, ishmael, floods, moses, acknowledge, crisis, strengthened, acacia,
# Nearest to first: antoninus, archie, spy, phi, in, gollancz, leagues, lifted,
# Nearest to on: in, agouti, for, poirot, by, at, and, airshow,
# Nearest to many: some, the, acacia, most, omega, even, public, archie,
# Nearest to see: cpu, ark, legal, is, xbox, victory, radial, seclusion,
# Average loss at step  32000 :  6.01121691847
# Average loss at step  34000 :  5.70199857652
# Average loss at step  36000 :  5.74869286239
# Average loss at step  38000 :  5.50272646439
# Average loss at step  40000 :  5.27398722732
# Nearest to be: have, according, by, been, was, were, is, jacobs,
# Nearest to one: two, four, eight, six, zero, three, seven, five,
# Nearest to its: their, the, his, kifl, this, operatorname, reacting, damaging,
# Nearest to other: another, archie, print, some, many, otimes, these, asymptotically,
# Nearest to often: droughts, there, also, expressions, it, not, still, amphibious,
# Nearest to their: its, his, the, archie, operatorname, aquila, kifl, ecb,
# Nearest to an: the, traveled, himself, melodic, almighty, sergei, serves, acacia,
# Nearest to will: would, can, could, may, but, she, puns, to,
# Nearest to and: or, but, zero, archie, abet, in, dasyprocta, divider,
# Nearest to also: which, dasyprocta, closing, unnecessary, not, protests, lady, it,
# Nearest to can: would, will, could, may, must, to, cannot, should,
# Nearest to such: far, ishmael, well, floods, strengthened, these, moses, tap,
# Nearest to first: antoninus, spy, archie, phi, leagues, albury, epistles, gollancz,
# Nearest to on: in, agouti, at, from, poirot, archie, dasyprocta, zero,
# Nearest to many: some, acacia, most, kifl, omega, the, these, several,
# Nearest to see: seclusion, cpu, is, ark, legal, xbox, radial, constitutional,
# Average loss at step  42000 :  5.38723493993
# Average loss at step  44000 :  5.24232714653
# Average loss at step  46000 :  5.22197512472
# Average loss at step  48000 :  5.20549657214
# Average loss at step  50000 :  4.98451475537
# Nearest to be: have, been, according, by, were, was, is, are,
# Nearest to one: two, four, three, eight, seven, six, five, operatorname,
# Nearest to its: their, the, his, chanter, kifl, this, operatorname, damaging,
# Nearest to other: another, these, archie, many, some, print, otimes, three,
# Nearest to often: also, still, there, commonly, droughts, eyewitnesses, not, expressions,
# Nearest to their: its, his, the, operatorname, archie, aquila, chanter, ecb,
# Nearest to an: traveled, himself, melodic, the, mutable, aoc, almighty, acacia,
# Nearest to will: would, can, could, may, must, to, but, puns,
# Nearest to and: or, but, eight, archie, abet, four, dasyprocta, seven,
# Nearest to also: which, not, often, unnecessary, closing, dasyprocta, it, lady,
# Nearest to can: will, would, could, may, must, cannot, to, should,
# Nearest to such: these, far, strengthened, ishmael, well, tap, medical, crisis,
# Nearest to first: kapoor, antoninus, spy, kennel, phi, archie, leagues, albury,
# Nearest to on: in, agouti, at, two, dasyprocta, and, from, for,
# Nearest to many: some, several, these, kifl, most, acacia, all, two,
# Nearest to see: seclusion, radial, legal, cpu, franchises, surveyed, xbox, accompany,
# Average loss at step  52000 :  5.03638391805
# Average loss at step  54000 :  5.17214620614
# Average loss at step  56000 :  5.04229146063
# Average loss at step  58000 :  5.05250226247
# Average loss at step  60000 :  4.93791117239
# Nearest to be: have, been, was, by, according, were, are, gundam,
# Nearest to one: two, four, three, seven, six, eight, five, operatorname,
# Nearest to its: their, the, his, her, chanter, directx, kifl, damaging,
# Nearest to other: many, these, some, another, archie, balboa, wct, otimes,
# Nearest to often: still, commonly, also, there, eyewitnesses, not, frequently, droughts,
# Nearest to their: its, his, the, her, operatorname, archie, aquila, michelob,
# Nearest to an: traveled, himself, melodic, the, tamed, serves, mutable, sergei,
# Nearest to will: would, can, could, may, must, to, but, does,
# Nearest to and: or, ursus, but, archie, abet, dasyprocta, including, wct,
# Nearest to also: which, dasyprocta, unnecessary, closing, often, michelob, who, not,
# Nearest to can: would, will, could, may, must, cannot, should, might,
# Nearest to such: these, well, far, strengthened, ishmael, tap, are, worth,
# Nearest to first: kapoor, antoninus, sher, last, albury, archie, agouti, ursus,
# Nearest to on: in, at, agouti, upon, from, poirot, during, paranoia,
# Nearest to many: some, several, these, most, kifl, all, other, acacia,
# Nearest to see: radial, seclusion, is, accompany, and, cpu, mata, xbox,
# Average loss at step  62000 :  5.01775521111
# Average loss at step  64000 :  4.83334156716
# Average loss at step  66000 :  4.5919899019
# Average loss at step  68000 :  4.97967352784
# Average loss at step  70000 :  4.90084503436
# Nearest to be: have, been, by, were, according, was, is, are,
# Nearest to one: six, two, five, four, seven, cebus, eight, three,
# Nearest to its: their, his, the, directx, chanter, her, reacting, kifl,
# Nearest to other: many, these, some, print, various, thaler, another, balboa,
# Nearest to often: commonly, still, also, frequently, there, generally, eyewitnesses, usually,
# Nearest to their: its, his, the, her, operatorname, michelob, chanter, kifl,
# Nearest to an: traveled, himself, the, melodic, tamed, serves, almighty, aoc,
# Nearest to will: would, can, could, may, must, to, does, cannot,
# Nearest to and: or, but, ursus, abet, archie, kapoor, including, four,
# Nearest to also: which, often, never, now, dasyprocta, unnecessary, closing, not,
# Nearest to can: would, will, could, may, must, cannot, should, might,
# Nearest to such: these, well, strengthened, far, formal, ishmael, other, tap,
# Nearest to first: kapoor, cebus, last, antoninus, sher, microcebus, leagues, kennel,
# Nearest to on: in, mico, upon, agouti, cebus, at, from, paranoia,
# Nearest to many: some, several, these, all, most, other, kifl, acacia,
# Nearest to see: radial, mata, ectopic, accompany, xbox, seclusion, franchises, kapoor,
# Average loss at step  72000 :  4.75967833388
# Average loss at step  74000 :  4.81564081609
# Average loss at step  76000 :  4.7286014241
# Average loss at step  78000 :  4.79009146526
# Average loss at step  80000 :  4.80479757982
# Nearest to be: have, been, were, by, was, according, refer, nine,
# Nearest to one: seven, two, six, cebus, five, four, agouti, three,
# Nearest to its: their, his, the, her, directx, chanter, reacting, kifl,
# Nearest to other: many, some, these, various, thaler, balboa, otimes, archie,
# Nearest to often: commonly, still, also, frequently, usually, generally, sometimes, there,
# Nearest to their: its, his, the, her, chanter, operatorname, michelob, aquila,
# Nearest to an: traveled, himself, melodic, serves, tamed, unanimity, aoc, almighty,
# Nearest to will: would, can, could, may, must, cannot, to, should,
# Nearest to and: or, but, ursus, dasyprocta, abet, archie, iit, microcebus,
# Nearest to also: which, often, now, never, still, unnecessary, dasyprocta, who,
# Nearest to can: could, would, will, may, must, cannot, should, might,
# Nearest to such: these, well, strengthened, known, far, formal, tap, other,
# Nearest to first: kapoor, last, iit, escuela, cebus, sher, sacco, antoninus,
# Nearest to on: in, mico, upon, agouti, at, cebus, dasyprocta, and,
# Nearest to many: some, several, these, all, other, most, kifl, those,
# Nearest to see: accompany, radial, mata, franchises, maximally, kapoor, merwara, seclusion,
# Average loss at step  82000 :  4.76821481502
# Average loss at step  84000 :  4.74948141849
# Average loss at step  86000 :  4.77765543818
# Average loss at step  88000 :  4.74060648251
# Average loss at step  90000 :  4.75209616733
# Nearest to be: been, have, were, was, according, by, refer, is,
# Nearest to one: two, four, seven, three, eight, six, five, cebus,
# Nearest to its: their, his, the, her, reacting, kifl, operatorname, directx,
# Nearest to other: many, some, various, these, thaler, otimes, wct, archie,
# Nearest to often: commonly, still, frequently, sometimes, usually, also, generally, there,
# Nearest to their: its, his, the, her, chanter, operatorname, ecb, aquila,
# Nearest to an: himself, traveled, melodic, the, unanimity, tamed, serves, sergei,
# Nearest to will: would, can, may, could, must, cannot, should, to,
# Nearest to and: or, but, ursus, including, in, dasyprocta, archie, iit,
# Nearest to also: which, often, now, still, never, unnecessary, dasyprocta, michelob,
# Nearest to can: will, may, could, would, must, should, cannot, might,
# Nearest to such: these, well, known, far, formal, overworld, tap, strengthened,
# Nearest to first: last, kapoor, iit, escuela, cebus, second, sher, sacco,
# Nearest to on: in, upon, mico, at, agouti, cebus, under, during,
# Nearest to many: some, several, these, all, most, kifl, other, those,
# Nearest to see: accompany, mata, maximally, radial, franchises, kapoor, merwara, address,
# Average loss at step  92000 :  4.65462833226
# Average loss at step  94000 :  4.72483561909
# Average loss at step  96000 :  4.69310496497
# Average loss at step  98000 :  4.58987879837
# Average loss at step  100000 :  4.70420959187
# Nearest to be: been, have, is, were, was, refer, by, according,
# Nearest to one: six, seven, eight, two, five, four, cebus, operatorname,
# Nearest to its: their, his, the, her, operatorname, kifl, chanter, reacting,
# Nearest to other: various, many, these, some, thaler, otimes, proscribed, print,
# Nearest to often: commonly, usually, frequently, still, sometimes, also, generally, there,
# Nearest to their: its, his, the, her, chanter, operatorname, aquila, ecb,
# Nearest to an: himself, traveled, melodic, achieved, tamed, unanimity, aoc, almighty,
# Nearest to will: would, can, could, may, must, should, cannot, to,
# Nearest to and: or, but, ursus, archie, dasyprocta, abet, including, iit,
# Nearest to also: which, often, now, never, still, who, dasyprocta, unnecessary,
# Nearest to can: will, could, may, would, must, should, cannot, might,
# Nearest to such: these, well, known, many, formal, overworld, far, tap,
# Nearest to first: last, kapoor, iit, second, cebus, escuela, sacco, sher,
# Nearest to on: in, upon, mico, agouti, at, under, cebus, through,
# Nearest to many: some, several, these, all, most, kifl, those, other,
# Nearest to see: maximally, accompany, radial, kapoor, mata, dddddd, ursus, merwara,

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
